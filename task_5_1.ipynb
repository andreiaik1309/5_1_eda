# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/data_enginer/ML/

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/data_enginer/ML

# %% [markdown]
# ## Задание 1

# %%
df = pd.read_csv('dataset_0.csv')

# %%
df.describe().T
# Out:
#              count      mean       std        min       25%       50%       75%        max
# feature_0   1014.0 -2.992791  4.586396 -18.683715 -5.375026 -0.712725  0.294861   3.571550
# feature_1   1014.0  0.354827  1.242543  -3.681904 -0.390112  0.228473  0.966569   5.228342
# feature_2   1014.0 -2.724893  5.773157 -43.557242 -3.001561 -0.660930  0.264393   5.802537
# feature_3   1014.0  0.503945  0.500231   0.000000  0.000000  1.000000  1.000000   1.000000
# feature_4   1014.0  0.989091  0.995562   0.000605  0.303611  0.646654  1.339636   8.114341
# feature_5   1014.0 -3.229856  5.915039 -25.162799 -5.159559 -0.476880  0.248068   7.297706
# feature_6   1014.0 -1.229476  2.292950 -13.434066 -2.189485 -0.643656  0.204153   3.353525
# feature_7   1014.0 -1.590139  4.132736 -22.105532 -1.752688 -0.499267  0.441035  11.095089
# feature_8   1014.0 -1.081217  2.389788  -9.498746 -1.752294 -0.355370  0.384618   3.790316
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   feature_0   1014 non-null   float64
#  1   feature_1   1014 non-null   float64
#  2   feature_2   1014 non-null   float64
#  3   feature_3   1014 non-null   int64
#  4   feature_4   1014 non-null   float64
#  5   feature_5   1014 non-null   float64
#  6   feature_6   1014 non-null   float64
#  7   feature_7   1014 non-null   float64
#  8   feature_8   1014 non-null   float64
#  9   feature_9   1014 non-null   float64
#  10  feature_10  1014 non-null   float64
#  11  feature_11  1014 non-null   float64
#  12  feature_12  1014 non-null   float64
#  13  feature_13  1014 non-null   float64
#  14  feature_14  1014 non-null   float64
#  15  feature_15  1014 non-null   float64
#  16  feature_16  1014 non-null   float64
#  17  feature_17  1014 non-null   float64
# ...

# %%
df.corr()
# Out:
#             feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  feature_7  feature_8  feature_9  feature_10  feature_11  feature_12  feature_13  feature_14  feature_15  feature_16  feature_17  feature_18  feature_19  feature_20     class
# feature_0    1.000000  -0.445882   0.718022   0.017232  -0.028595   0.876545   0.770567   0.610861   0.799336  -0.840904    0.761964    0.518182    0.885888    0.012229    0.883214    0.599685    0.897690   -0.024251   -0.668025   -0.898814    0.006929 -0.691809
# feature_1   -0.445882   1.000000  -0.348553   0.012270   0.017090  -0.590349  -0.329847  -0.395517  -0.558050   0.314252   -0.314873   -0.234854   -0.408947    0.010043   -0.356307   -0.304719   -0.614727   -0.033194    0.223118    0.390742   -0.031722  0.254709
# ...

# %% [markdown]
# Гипотеза: feature_3, feature_4, feature_13, feature_17, feature_20 могут являться случайным шумом и не имеют значимой корреляции или влияния на другие переменные в датасете; НО это не значит, что эти фичи надо исключать из модели, они могут оказывать более сложное (не линейное) влияние на целевую переменную

# %% [markdown]
# ## Задание 2

# %%
df1 = pd.read_csv('dataset_1.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature_1  1000 non-null   float64
#  1   feature_2  1000 non-null   float64
#  2   target     1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %%
df1.describe()
# Out:
#          feature_1    feature_2      target
# count  1000.000000  1000.000000  1000.00000
# mean      0.001016     0.000118     0.50000
# std       0.641268     0.640570     0.50025
# min      -1.042947    -1.055231     0.00000
# 25%      -0.621492    -0.621425     0.00000
# 50%       0.005128    -0.001786     0.50000
# 75%       0.617814     0.619077     1.00000
# max       1.048049     1.070260     1.00000

# %%
df1.hist()
plt.show()

# %%
seaborn.pairplot(df1, hue ='target')
plt.show()

# %%
df1
# Out:
#      feature_1  feature_2  target
# 0    -0.532193   0.814028       0
# 1    -0.212750   1.011712       0
# 2     0.306720   0.959148       0
# 3     0.786851  -0.031955       1
# 4    -0.239004  -0.757634       1
# ..         ...        ...     ...
# 995  -0.782726   0.291151       1
# 996   0.377208   0.694450       1
# 997  -0.387858   0.706282       1
# 998  -0.966058   0.249970       0
# 999  -0.269648  -0.737153       1
#
# [1000 rows x 3 columns]

# %%
df1['feature_1']**2 + df1['feature_2']**2
# Out:
# 0      0.945871
# 1      1.068825
# 2      1.014043
# 3      0.620156
# 4      0.631131
#          ...
# 995    0.697429
# 996    0.624546
# 997    0.649268
# 998    0.995754
# 999    0.616104
# Length: 1000, dtype: float64

# %% [markdown]
# Гипотеза: целевая переменная зависит от фичей по уравнению
# окружности
